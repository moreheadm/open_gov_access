# %%
import pandas as pd

# %%
# import xls file
df_list = pd.read_html("/Users/tamuzhod/open_gov_access/data/votes_sample.xls")  # returns a list of tables
df_votes = df_list[0]                           # pick the first table

df_list = pd.read_html("/Users/tamuzhod/open_gov_access/data/legesliations_sample.xls")  # returns a list of tables
df_legislation = df_list[0]                           # pick the first table

# %%
df_legislation.head()
# Out:
#    File # Enactment #                                               Name  \
# 0  251098         NaN  Hearing - Appeal of Conditional Use Authorizat...
# 1  251121         NaN  Liquor License Transfer - 895 O'Farrell Street...
# 2  251120         NaN  Hearing - Airborne Plutonium at Hunters Point ...
# 3  251119         NaN  Supporting Immigrant Communities and Local Aut...
# 4  251118         NaN  Sikh Awareness and Appreciation Month - Novemb...
#
#          Type                    Status  Introduced Final Action  \
# 0     Hearing                     Filed  10/27/2025    11/6/2025
# 1     Hearing  Pending Committee Action   11/7/2025          NaN
# 2     Hearing  Pending Committee Action   11/4/2025          NaN
# 3  Resolution    For Immediate Adoption   11/4/2025          NaN
# 4  Resolution    For Immediate Adoption   11/4/2025          NaN
#
#                                                Title
# 0  Hearing of persons interested in or objecting ...
# ...

# %%
df_votes.head()
# Out:
#      File # Action Date                                              Title  \
# 0       NaN         NaN                                                NaN
# 1  250782.0  10/29/2025  Ordinance amending the Administrative Code to ...
# 2  250782.0  10/29/2025  Ordinance amending the Administrative Code to ...
# 3  251020.0  10/29/2025  Hearing to consider the release of reserved fu...
# 4  251017.0  10/29/2025  Resolution exempting from the competitive bidd...
#
#   Vote                  Meeting Body
# 0  NaN                           NaN
# 1  Aye  Budget and Finance Committee
# 2  Aye  Budget and Finance Committee
# 3  Aye  Budget and Finance Committee
# 4  Aye  Budget and Finance Committee
